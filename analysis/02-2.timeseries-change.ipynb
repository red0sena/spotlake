# %%
import pickle
import pandas as pd
from tqdm import tqdm
import matplotlib.pyplot as plt

# %%
df_dict = pickle.load(open('./df_dict.pkl', 'rb'))
iaz_list = list(df_dict.keys())

# %%
df_dict[iaz_list[0]].head()
# Out:
#                      InstanceType          Region AvailabilityZoneId  Score  \
# i-az
# a1.2xlarge_apne1-az2   a1.2xlarge  ap-northeast-1          apne1-az2      3
# a1.2xlarge_apne1-az2   a1.2xlarge  ap-northeast-1          apne1-az2      3
# a1.2xlarge_apne1-az2   a1.2xlarge  ap-northeast-1          apne1-az2      3
# a1.2xlarge_apne1-az2   a1.2xlarge  ap-northeast-1          apne1-az2      3
# a1.2xlarge_apne1-az2   a1.2xlarge  ap-northeast-1          apne1-az2      3
#
#                       Frequency  Price             TimeStamp_sps  \
# i-az
# a1.2xlarge_apne1-az2          1  0.069 2021-11-23 00:12:08+00:00
# a1.2xlarge_apne1-az2          1  0.069 2021-11-23 00:22:03+00:00
# a1.2xlarge_apne1-az2          1  0.069 2021-11-23 00:31:56+00:00
# a1.2xlarge_apne1-az2          1  0.069 2021-11-23 00:41:59+00:00
# a1.2xlarge_apne1-az2          1  0.069 2021-11-23 00:51:59+00:00
#
#                             TimeStamp_spotinfo
# i-az
# a1.2xlarge_apne1-az2 2021-11-23 00:08:16+00:00
# a1.2xlarge_apne1-az2 2021-11-23 00:18:16+00:00
# a1.2xlarge_apne1-az2 2021-11-23 00:28:16+00:00
# a1.2xlarge_apne1-az2 2021-11-23 00:38:15+00:00
# a1.2xlarge_apne1-az2 2021-11-23 00:48:15+00:00

# %% [markdown]
# ### 01. Calculate Change Frequency

# %%
# calcaulte change frequency

iaz_statistic_dict = {}

for iaz in tqdm(iaz_list):
    iaz_df = df_dict[iaz]
    score_change = (iaz_df['Score'].diff() > 0).sum()
    frequency_change = (iaz_df['Frequency'].diff() > 0).sum()
    price_change = (iaz_df['Price'].diff() > 0).sum()
    
    iaz_statistic_dict[iaz] = [score_change, frequency_change, price_change]
# Out:
# 100%|██████████| 14904/14904 [00:24<00:00, 609.32it/s]

# %% [markdown]
# ### 02. Time-series Visualization

# %%
def time_vis(iaz):
    cond_df = df_dict[iaz].sort_values(by='TimeStamp_spotinfo').reset_index()
    
    fig, ax1 = plt.subplots()    
    fig.set_figheight(7)
    fig.set_figwidth(15)
    
    ax1.plot(cond_df['Score'], label='SPS', color='tab:red')
    ax1.set_ylim((0, 4))
    ax1.set_ylabel('SPS')
    
    ax2 = ax1.twinx()
    ax2.plot(cond_df['Price'], label='Price', color='tab:blue')
    
    ax3 = ax1.twinx()
    ax3.plot(cond_df['Frequency'], label='FS', color='tab:green')
    ax3.set_ylim((0, 6))
    ax3.set_ylabel('\n\nPrice & FS')

    lines, labels = ax1.get_legend_handles_labels()
    lines2, labels2 = ax2.get_legend_handles_labels()
    lines3, labels3 = ax3.get_legend_handles_labels()
    ax3.legend(lines + lines2 + lines3, labels + labels2 + labels3,fontsize=10, loc=5)
    
    plt.show()

# %% [markdown]
# ### 03. SPS, FS, Price, Multiply Visualization

# %%
max_iaz = ''
max_stat = 0
for iaz, stats in iaz_statistic_dict.items():
    if stats[0] > max_stat:
        max_stat = stats[0]
        max_iaz = iaz
        
print(f"I-AZ: {max_iaz} // Maximum Change: {max_stat}")
time_vis(max_iaz)
# Out:
# I-AZ: g4dn.xlarge_apne2-az3 // Maximum Change: 365

# %%
max_iaz = ''
max_stat = 0
for iaz, stats in iaz_statistic_dict.items():
    if stats[1] > max_stat:
        max_stat = stats[1]
        max_iaz = iaz

print(f"I-AZ: {max_iaz} // Maximum Change: {max_stat}")
time_vis(max_iaz)
# Out:
# I-AZ: c5d.24xlarge_euw2-az1 // Maximum Change: 6

# %%
max_iaz = ''
max_stat = 0
for iaz, stats in iaz_statistic_dict.items():
    if stats[2] > max_stat:
        max_stat = stats[2]
        max_iaz = iaz
        
print(f"I-AZ: {max_iaz} // Maximum Change: {max_stat}")
time_vis(max_iaz)
# Out:
# I-AZ: g5.xlarge_use1-az1 // Maximum Change: 69

# %%
max_iaz = ''
max_stat = 0
for iaz, stats in iaz_statistic_dict.items():
    stat_sum = sum(stats)
    if stat_sum > max_stat:
        max_stat = stat_sum
        max_iaz = iaz
        
print(f"I-AZ: {max_iaz} // Maximum Change: {max_stat}")
time_vis(max_iaz)
# Out:
# I-AZ: g4dn.xlarge_apne2-az3 // Maximum Change: 365

# %%
max_iaz = ''
max_stat = 0
for iaz, stats in iaz_statistic_dict.items():
    stat_mul = stats[0] * stats[1] * stats[2]
    if stat_mul > max_stat:
        max_stat = stat_mul
        max_iaz = iaz
        
print(f"I-AZ: {max_iaz} // Maximum Change: {max_stat}")
time_vis(max_iaz)
# Out:
# I-AZ: r5ad.12xlarge_apse1-az3 // Maximum Change: 10404
